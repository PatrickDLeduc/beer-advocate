# %%
# standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# web scraping imports
import requests
from bs4 import BeautifulSoup

# %%
# reading the data
df = pd.read_csv('full_data_cleaned.csv')

# %%
# creating the urls
beer_info_page = df['beer_info_page']
beer_info_page

page_urls = ['https://www.beeradvocate.com' + page for page in beer_info_page]
page_urls
# Out:
# 0             /beer/profile/39/131/
# 1           /beer/profile/911/2899/
# 2        /beer/profile/1432/556187/
# 3       /beer/profile/32906/547137/
# 4            /beer/profile/252/779/
#                    ...
# 8760    /beer/profile/35633/201871/
# 8761    /beer/profile/31540/187158/
# 8762    /beer/profile/33018/102888/
# 8763    /beer/profile/40927/131389/
# 8764    /beer/profile/32319/145691/
# Name: beer_info_page, Length: 8765, dtype: object

# %%
# Using requests to get the main page
url = 'https://www.beeradvocate.com/beer/profile/39/131/'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# isolating the Notes sections
soup.find_all(style='clear:both; margin:0; padding:0px 20px; font-size:1.05em;')[0].text.strip()
# Out:
# 'Notes:\nA beer that has a dominant malty taste. This beer’s origins in a monk’s recipe are reflected in its heartiness. The Pope of Beers, Conrad Seidl, describes it as: “Almost black with a very slight red tone, a sensational, festive foam and truly extraordinary fragrance that at first summons up visions of greaves lard. The first taste is of mild fullness with an accompanying coffee tone, which becomes more dominant with the aftertaste. There is very little of the sweetness that is frequently to be tasted with doppelbock beer.” The Ayinger Celebrator has been ranked among the best beers of the world by the Chicago Testing Institute several times and has won numerous medals.'

# %%
url = 'https://www.beeradvocate.com/beer/profile/741/399497/'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')
soup.find_all(style='clear:both; margin:0; padding:0px 20px; font-size:1.05em;')[0].text.strip()
# Out:
# 'Notes:\nNone'

# %%
# This function gets the notes, otherwise returns NaN
def get_notes(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    if soup.find_all(style='clear:both; margin:0; padding:0px 20px; font-size:1.05em;'):
        notes = soup.find_all(style='clear:both; margin:0; padding:0px 20px; font-size:1.05em;')[0].text.strip()
    else:
        notes = np.nan
    return notes

# %%
beer_notes = pd.Series(page_urls).apply(get_notes)

# %%
# beer_notes[3].replace('Notes:\n', '')
df['notes'] = beer_notes.apply(lambda x: x.replace('Notes:\n', '', 1))

# %%
# replace None with np.nan
df
# Out:
#                            name  rank  \
# 0            Ayinger Celebrator     1
# 1             Doppelbock Dunkel     2
# 2             Convex Refraction     3
# 3                     Indikator     4
# 4     Weihenstephaner Korbinian     5
# ...                         ...   ...
# 8760             The Cut: Peach    96
# 8761                  Roseberry    97
# 8762                Ensorcelled    98
# 8763               Befuddlement    99
# 8764                      Raspe   100
#
#                                       brewery              style  n_ratings  \
# 0                      Ayinger Privatbrauerei  Bock - Doppelbock       6976
# 1                     Klosterbrauerei Andechs  Bock - Doppelbock       1316
# 2                    Jackie O's Pub & Brewery  Bock - Doppelbock         24
# 3                          Schilling Beer Co.  Bock - Doppelbock         12
# 4     Bayerische Staatsbrauerei Weihenstephan  Bock - Doppelbock       2968
# ...                                       ...                ...        ...
# 8760                 Casey Brewing & Blending           Wild Ale         82
# 8761                         de Garde Brewing           Wild Ale         81
# 8762                          The Rare Barrel           Wild Ale        346
# 8763                           Bruery Terreux           Wild Ale        245
# 8764                     Side Project Brewing           Wild Ale        105
#
#       avg_rating               beer_info_page   abv  BA_official_score  \
# 0           4.34        /beer/profile/39/131/   6.7               96.0
# 1           4.28      /beer/profile/911/2899/   7.1               95.0
# 2           4.42   /beer/profile/1432/556187/  13.7               95.0
# 3           4.49  /beer/profile/32906/547137/   8.0               94.0
# 4           4.20       /beer/profile/252/779/   7.4               93.0
# ...          ...                          ...   ...                ...
# 8760        4.36  /beer/profile/35633/201871/   5.0               96.0
# 8761        4.36  /beer/profile/31540/187158/   6.2               96.0
# 8762        4.34  /beer/profile/33018/102888/   5.8               96.0
# 8763        4.34  /beer/profile/40927/131389/   9.9               96.0
# 8764        4.35  /beer/profile/32319/145691/   6.0               96.0
#
#       ranking_vs_all  ...  status             last_rated  date_added n_wants  \
# 0                883  ...  Active           May 21, 2022  2001-01-10     623
# 1               1546  ...  Active           May 25, 2022  2002-06-16     450
# 2               1772  ...  Active           May 09, 2022  2021-06-26       1
# 3               2641  ...  Active           Apr 16, 2022  2021-05-01       1
# 4               2948  ...  Active           May 30, 2022  2001-09-12     251
# ...              ...  ...     ...                    ...         ...     ...
# 8760            1157  ...  Active  Yesterday at 11:56 PM  2015-11-30      22
# 8761            1171  ...  Active           Sep 05, 2021  2015-08-21      16
# 8762             991  ...  Active           Jul 10, 2021  2013-10-21      88
# 8763            1028  ...  Active           Oct 10, 2021  2014-07-30      59
# 8764            1143  ...  Active           Jan 30, 2022  2014-11-15      29
#
#      n_gots  country          state style_family    substyle  \
# 0      1142  Germany            NaN         Bock  Doppelbock
# 1       192  Germany            NaN         Bock  Doppelbock
# 2         0      USA           Ohio         Bock  Doppelbock
# 3         0      USA  New Hampshire         Bock  Doppelbock
# 4       399  Germany            NaN         Bock  Doppelbock
# ...     ...      ...            ...          ...         ...
# 8760     12      USA       Colorado     Wild Ale         NaN
# 8761     11      USA         Oregon     Wild Ale         NaN
# 8762     82      USA     California     Wild Ale         NaN
# 8763     38      USA     California     Wild Ale         NaN
# 8764     13      USA       Missouri     Wild Ale         NaN
#
#                                                   notes
# 0     A beer that has a dominant malty taste. This b...
# 1     This world famous bock from Bavaria’s Holy Mou...
# 2     Collaboration with Burial\n\nBourbon Barrel Ag...
# 3                                                  None
# 4     Our Korbinian, the full-bodied, dark Doppelboc...
# ...                                                 ...
# 8760                                               None
# 8761  A golden wild ale, aged in oak wine barrels, t...
# 8762                                               None
# 8763  Hoarders Society exclusive blend of our Sour I...
# 8764  American wild ale fermented and aged in Chambo...
#
# [8765 rows x 22 columns]

# %%
# removing newline characters
df['notes'] = df['notes'].apply(lambda x: x.replace('\n', ' '))

# %%
# Saving the data
df.to_csv('beeradvocate_full_data.csv', index=False)
